# %%
import sounddevice as sd
from scipy.io.wavfile import write


duration = 5

sample_rate = 44100

print("🎤 Speak now...")

audio = sd.rec(
    int(duration * sample_rate),
    samplerate=sample_rate,
    channels=1,
    dtype="int16"
)

sd.wait()

write("input.wav", sample_rate, audio)

print("✅ Recording saved as input.wav")
# Out:
# 🎤 Speak now...
# ✅ Recording saved as input.wav

# %%
import whisper

print("Loading Whisper model...")

model = whisper.load_model("base")

print("Converting speech to text...")

result = model.transcribe("input.wav")

text = result["text"]

print("You said:")
print(text)
# Out:
# Loading Whisper model...
# Converting speech to text...
# c:\Users\asayl\anaconda3\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# You said:
#  Hi, my name is Asiah, can you give me a cute nickname?

# %%
import cohere

co = cohere.Client("W8Tig8KQ0S6te5GhgPI5tdgpBQ6UXnW8E5hmHN6q")

response = co.chat(
    model="command-r-08-2024",
    message=text
)

print(response.text)
# Out:
# Sure, Asiah! Here are a few cute nickname options for you:
#
# - Asi
# - Azie
# - As-As
# - Ash
# - Sunny (a play on your name, as it brings sunshine to people's lives)
# - Star (a shining and bright nickname)
# - Mia (a sweet and short option)
#
# Do any of these nicknames resonate with you? I can offer some more suggestions if you'd like!

# %%
from gtts import gTTS
import os


tts = gTTS(text=response.text, lang="en")

tts.save("response.mp3")

print("✅ Audio saved!")

os.startfile("response.mp3")
# Out:
# ✅ Audio saved!
